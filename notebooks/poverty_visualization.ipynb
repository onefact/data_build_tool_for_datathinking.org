# %% [markdown]
# # Data download
#
# https://www.neighborhoodatlas.medicine.wisc.edu/

# %%
# Load duckdb, which lets us efficiently load large files
import duckdb

# Load pandas, which lets us manipulate dataframes
import pandas as pd

# Load polars, which enables loading of parquet files
import polars as pl

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql

# Set configrations on jupysql to directly output data to Pandas and to simplify the output that is printed to the notebook.
# %config SqlMagic.autopandas = True

# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Connect jupysql to DuckDB using a SQLAlchemy-style connection string. Either connect to an in memory DuckDB, or a file backed db.
# %sql duckdb:///:memory:

# %% [markdown]
# ## Minimal duckdb query to standardize the ADI file
#
# Prompt for Claude:
#
# ```
# %%sql
# SELECT *
# FROM read_csv('https://data.cityofnewyork.us/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD',
#     header=True,
#     delim=',',
#     quote='"',
#     columns={'Unique Key': 'BIGINT',
#     'Created Date': 'VARCHAR',
#     'Closed Date': 'VARCHAR',
#     'Agency': 'VARCHAR',
#     'Agency Name': 'VARCHAR',
#     'Complaint Type': 'VARCHAR',
#     'Descriptor': 'VARCHAR',
#     'Location Type': 'VARCHAR',
#     'Incident Zip': 'VARCHAR',
#     'Incident Address': 'VARCHAR',
#     'Street Name': 'VARCHAR',
#     'Cross Street 1': 'VARCHAR',
#     'Cross Street 2': 'VARCHAR',
#     'Intersection Street 1': 'VARCHAR',
#     'Intersection Street 2': 'VARCHAR',
#     'Address Type': 'VARCHAR',
#     'City': 'VARCHAR',
#     'Landmark': 'VARCHAR',
#     'Facility Type': 'VARCHAR',
#     'Status': 'VARCHAR',
#     'Due Date': 'VARCHAR',
#     'Resolution Description': 'VARCHAR',
#     'Resolution Action Updated Date': 'VARCHAR',
#     'Community Board': 'VARCHAR',
#     'BBL': 'VARCHAR',
#     'Borough': 'VARCHAR',
#     'X Coordinate (State Plane)': 'VARCHAR',
#     'Y Coordinate (State Plane)': 'VARCHAR',
#     'Open Data Channel Type': 'VARCHAR',
#     'Park Facility Name': 'VARCHAR',
#     'Park Borough': 'VARCHAR',
#     'Vehicle Type': 'VARCHAR',
#     'Taxi Company Borough': 'VARCHAR',
#     'Taxi Pick Up Location': 'VARCHAR',
#     'Bridge Highway Name': 'VARCHAR',
#     'Bridge Highway Direction': 'VARCHAR',
#     'Road Ramp': 'VARCHAR',
#     'Bridge Highway Segment': 'VARCHAR',
#     'Latitude': 'DOUBLE',
#     'Longitude': 'DOUBLE',
#     'Location': 'VARCHAR'})
# LIMIT 10;
#
# Please use the above query example and rewrite it for the file at `/Users/me/Downloads/adi-download/US_2021_ADI_Census\ Block\ Group_v4.csv` that has the following header:
#
# ```"","GISJOIN","ADI_NATRANK","ADI_STATERNK","FIPS"
# "1","G01000100201001","74","5","010010201001"
# "2","G01000100201002","74","5","010010201002"
# "3","G01000100202001","84","7","010010202001"
# "4","G01000100202002","84","7","010010202002"
# "5","G01000100203001","79","6","010010203001"
# "6","G01000100203002","79","6","010010203002"
# "7","G01000100204001","64","3","010010204001"
# "8","G01000100204002","64","3","010010204002"
# "9","G01000100204003","64","3","010010204003"
# ```
# ```

# %%
# %%sql
# SELECT *
# FROM read_csv('/Users/brenstockdale/Downloads/Data Downloads/adi-download-usa/US_2021_ADI_Census Block Group_v4.csv',
#   header=True,
#   delim=',',
#   quote='"',
#   skip=2,
#   columns={'INDEX': 'INT',
#            'GISJOIN': 'VARCHAR',
#            'ADI_NATRANK': 'VARCHAR',
#            'ADI_STATERNK': 'VARCHAR',
#            'FIPS': 'VARCHAR'})
# LIMIT 10;
# Out:
#    INDEX          GISJOIN ADI_NATRANK ADI_STATERNK          FIPS
# 0      3  G01000100202001          84            7  010010202001
# 1      4  G01000100202002          84            7  010010202002
# 2      5  G01000100203001          79            6  010010203001
# 3      6  G01000100203002          79            6  010010203002
# 4      7  G01000100204001          64            3  010010204001
# 5      8  G01000100204002          64            3  010010204002
# 6      9  G01000100204003          64            3  010010204003
# 7     10  G01000100204004          64            3  010010204004
# 8     11  G01000100205011          65            4  010010205011
# 9     12  G01000100205012          65            4  010010205012

# %%
# %%sql
# CREATE TABLE test (
#     name            VARCHAR,
#     ind             INT,
# );
# Out:
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
# %%sql
# INSERT INTO test VALUES ('first', 1);
# Out:
#    Count
# 0      1

# %%
# %%sql
# INSERT INTO test VALUES ('second', NULL);
# Out:
#    Count
# 0      1

# %%
# %%sql
# DESCRIBE test;
# Out:
#   column_name column_type null  key default  extra
# 0        name     VARCHAR  YES  NaN     NaN    NaN
# 1         ind     INTEGER  YES  NaN     NaN    NaN

# %%
# %%sql
# SELECT * FROM test;
# Out:
#      name  ind
# 0   first  1.0
# 1  second  NaN

# %% [markdown]
# # Testing visualizations using a parquet file

# %%
import vegafusion as vf
import polars as pl
import altair as alt
#from vega_datasets import data
alt.data_transformers.disable_max_rows()
alt.renderers.enable('html')

# Configure DuckDB connection
vf.runtime.set_connection("duckdb")

# Enable Mime Renderer
vf.enable(row_limit=100000000)
# Out:
# vegafusion.enable(mimetype='html', row_limit=100000000, embed_options=None)

# %%
area_deprivation_index = pl.read_parquet('/Users/brenstockdale/Downloads/Data Downloads/poverty.parquet')

# %%
area_deprivation_index[50:70]
# Out:
# shape: (20, 6)
# ┌───────┬─────────────┬──────────────────┬────────┬──────────┬──────────┐
# │ TBLID ┆ GEOID       ┆ GEONAME          ┆ PROFLN ┆ ESTIMATE ┆ MG_ERROR │
# │ ---   ┆ ---         ┆ ---              ┆ ---    ┆ ---      ┆ ---      │
# │ str   ┆ str         ┆ str              ┆ i64    ┆ f64      ┆ str      │
# ╞═══════╪═════════════╪══════════════════╪════════╪══════════╪══════════╡
# │ R1701 ┆ 0400000US39 ┆ Ohio             ┆ 55     ┆ 13.4     ┆ +/-0.3   │
# │ R1701 ┆ 0400000US40 ┆ Oklahoma         ┆ 55     ┆ 15.6     ┆ +/-0.4   │
# │ R1701 ┆ 0400000US41 ┆ Oregon           ┆ 55     ┆ 12.2     ┆ +/-0.4   │
# │ R1701 ┆ 0400000US42 ┆ Pennsylvania     ┆ 55     ┆ 12.1     ┆ +/-0.2   │
# │ …     ┆ …           ┆ …                ┆ …      ┆ …        ┆ …        │
# │ R1701 ┆ 0400000US72 ┆ Puerto Rico      ┆ 55     ┆ 40.5     ┆ +/-0.9   │
# │ R1701 ┆ 0400001US01 ┆ Alabama -- Urban ┆ 55     ┆ 17.9     ┆ +/-0.7   │
# │ R1701 ┆ 0400001US02 ┆ Alaska -- Urban  ┆ 55     ┆ 9.4      ┆ +/-1.3   │
# │ R1701 ┆ 0400001US04 ┆ Arizona -- Urban ┆ 55     ┆ 12.6     ┆ +/-0.4   │
# └───────┴─────────────┴──────────────────┴────────┴──────────┴──────────┘

# %% [markdown]
# ## Load FIPS / GEOID from census data

# %%
# %%sql
# CREATE TABLE census_blocks AS SELECT * FROM 'https://public.datathinking.org/census.gov%2Fcensus_block_groups_latitude_longitude.parquet'
# Out:
#     Count
# 0  242384

# %%
# %%sql
#
# SELECT * FROM census_blocks LIMIT 20;
# Out:
#            GEOID   latitude   longitude
# 0   060590422062  33.451279 -117.649586
# 1   060376025051  33.907370 -118.341669
# 2   060590421092  33.442898 -117.598564
# 3   360810113002  40.776412  -73.908686
# 4   360290059004  42.937805  -78.901426
# 5   360050442003  40.904587  -73.845400
# 6   060855033123  37.353520 -121.798139
# 7   360290024002  42.894579  -78.806804
# 8   060590018014  33.860834 -117.979217
# 9   360610247005  40.839305  -73.944775
# 10  060374331033  34.065024 -118.049317
# 11  360470946001  40.647080  -73.924776
# 12  060372380005  33.948477 -118.314120
# 13  360290087005  42.962264  -78.874355
# 14  080590102131  39.818105 -105.062769
# 15  080310044044  39.734255 -104.899955
# 16  080310014014  39.694934 -105.020355
# 17  080050846002  39.629793 -104.796631
# 18  080050067093  39.570325 -104.891811
# 19  080010086064  39.979686 -104.826361

# %%
# %%sql
# CREATE TABLE poverty_percent AS SELECT * FROM '/Users/brenstockdale/Downloads/Data Downloads/poverty.parquet'
# Out:
#    Count
# 0   7285

# %%
poverty_df = pd.read_parquet('/Users/brenstockdale/Downloads/Data Downloads/poverty.parquet')

# %%
poverty_df.head()
# Out:
#    TBLID      GEOID                                            GEONAME  \
# 0  R1701  0100000US                                      United States
# 1  R1701  0100001US                             United States -- Urban
# 2  R1701  0100043US                             United States -- Rural
# 3  R1701  0100089US  United States -- American Indian Reservation a...
# 4  R1701  0100091US  United States -- Oklahoma Tribal Statistical Area
#
#    PROFLN  ESTIMATE MG_ERROR
# 0      55      12.8   +/-0.1
# 1      55      13.2   +/-0.1
# 2      55      10.9   +/-0.1
# 3      55      23.4   +/-0.8
# 4      55      15.8   +/-0.5

# %%
#poverty_df = poverty_df.rename(columns={"'TBLID'": "TBLID"})
#poverty_df = poverty_df.rename(columns={"'GEOID'": "GEOID"})
#poverty_df = poverty_df.rename(columns={"'GEONAME'": "GEONAME"})
#poverty_df = poverty_df.rename(columns={"'PROFLN'": "PROFLN"})
#poverty_df = poverty_df.rename(columns={"'ESTIMATE'": "ESTIMATE"})
#poverty_df = poverty_df.rename(columns={"'MG_ERROR'": "MG_ERROR"})

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7285 entries, 0 to 7284
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TBLID     7285 non-null   object
#  1   GEOID     7285 non-null   object
#  2   GEONAME   7285 non-null   object
#  3   PROFLN    7285 non-null   int64
#  4   ESTIMATE  7285 non-null   float64
#  5   MG_ERROR  7285 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 341.6+ KB

# %%
# %%sql
# UPDATE poverty_percent
# SET GEONAME = REPLACE(GEOID, 'US', '')
# WHERE GEONAME LIKE '%US'

# %%
# %%sql
# CREATE TABLE poverty_county AS
# SELECT * FROM poverty_percent WHERE (INSTR(GEONAME, 'County') > 0) OR (INSTR(GEONAME, 'county') > 0)
# Out:
#    Count
# 0   2689

# %%
# %%sql
# SELECT * FROM poverty_county LIMIT 1000;
# Out:
#      TBLID           GEOID                                            GEONAME  \
# 0    R1701  0500000US01003                            Baldwin County, Alabama
# 1    R1701  0500000US01015                            Calhoun County, Alabama
# 2    R1701  0500000US01043                            Cullman County, Alabama
# 3    R1701  0500000US01049                             DeKalb County, Alabama
# 4    R1701  0500000US01051                             Elmore County, Alabama
# ..     ...             ...                                                ...
# 802  R1701    330M600US356           Macon-Bibb County--Warner Robins, GA CSA
# 803  R1701  400C100US03763     Athens-Clarke County, GA Urbanized Area (2010)
# 804  R1701  400C100US04222  Augusta-Richmond County, GA--SC Urbanized Area...
# 805  R1701  400C100US43669  Kailua (Honolulu County)--Kaneohe, HI Urbanize...
# 806  R1701  400C100US51755  Louisville/Jefferson County, KY--IN Urbanized ...
#
#      PROFLN  ESTIMATE MG_ERROR
# 0        55      10.8   +/-2.2
# 1        55      19.8   +/-3.5
# 2        55      13.0   +/-3.7
# 3        55      21.3   +/-4.6
# 4        55      11.5   +/-3.2
# ..      ...       ...      ...
# 802      55      17.0   +/-2.0
# 803      55      20.2   +/-3.0
# 804      55      16.2   +/-2.0
# 805      55       6.5   +/-2.3
# 806      55      13.3   +/-1.1
#
# [807 rows x 6 columns]

# %%
# %%sql
#
# DELETE FROM poverty_county WHERE length(GEOID) > 14;
# Out:
#    Count
# 0      0

# %%
# %%sql
#
# SELECT * FROM poverty_percent LIMIT 1000;
# Out:
#      TBLID           GEOID                                        GEONAME  \
# 0    R1701  0500000US01003                        Baldwin County, Alabama
# 1    R1701  0500000US01015                        Calhoun County, Alabama
# 2    R1701  0500000US01043                        Cullman County, Alabama
# 3    R1701  0500000US01049                         DeKalb County, Alabama
# 4    R1701  0500000US01051                         Elmore County, Alabama
# ..     ...             ...                                            ...
# 995  R1701  310M600US22060            Faribault-Northfield, MN Micro Area
# 996  R1701  310M600US22100                      Farmington, MO Micro Area
# 997  R1701  310M600US22140                      Farmington, NM Metro Area
# 998  R1701  310M600US22180                    Fayetteville, NC Metro Area
# 999  R1701  310M600US22220  Fayetteville-Springdale-Rogers, AR Metro Area
#
#      PROFLN  ESTIMATE MG_ERROR
# 0        55      10.8   +/-2.2
# 1        55      19.8   +/-3.5
# 2        55      13.0   +/-3.7
# 3        55      21.3   +/-4.6
# 4        55      11.5   +/-3.2
# ..      ...       ...      ...
# 995      55       9.1   +/-2.9
# 996      55      18.6   +/-5.0
# 997      55      26.7   +/-3.6
# 998      55      14.8   +/-1.1
# 999      55       9.8   +/-1.1
#
# [1000 rows x 6 columns]

# %%
# %%sql
#
# DELETE FROM poverty_county WHERE (INSTR(GEONAME, 'County') > 0) OR (INSTR(GEONAME, 'county') > 0)

# %%
# %%sql
#
# SELECT * FROM census_blocks LIMIT 10;
# Out:
#           GEOID   longitude STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 0  320030016112 -115.069852      32      003  001611        2
# 1  320050011001 -119.732187      32      005  001100        1
# 2  320030019011 -115.128058      32      003  001901        1
# 3  320310035102 -119.737654      32      031  003510        2
# 4  320030002042 -115.166600      32      003  000204        2
# 5  320310035173 -119.673950      32      031  003517        3
# 6  320310032073 -119.750902      32      031  003207        3
# 7  350619703062 -106.668706      35      061  970306        2
# 8  350280005004 -106.290577      35      028  000500        4
# 9  360179702022  -75.728929      36      017  970202        2
#
#                 AFFGEOID NAME       NAMELSAD LSAD      ALAND   latitude
# 0  1500000US320030016112    2  Block Group 2   BG     663342  36.148129
# 1  1500000US320050011001    1  Block Group 1   BG    2022004  38.883508
# 2  1500000US320030019011    1  Block Group 1   BG     209570  36.141856
# 3  1500000US320310035102    2  Block Group 2   BG     594717  39.588675
# 4  1500000US320030002042    2  Block Group 2   BG    1144494  36.150667
# 5  1500000US320310035173    3  Block Group 3   BG     625323  39.612950
# 6  1500000US320310032073    3  Block Group 3   BG   25566087  39.305116
# 7  1500000US350619703062    2  Block Group 2   BG    8828015  34.778454
# 8  1500000US350280005004    4  Block Group 4   BG   53076356  35.802870
# 9  1500000US360179702022    2  Block Group 2   BG  114826135  42.655981

# %%
# %%sql
#
# SELECT * FROM census_blocks WHERE AFFGEOID LIKE '%500000US01003%'
# Out:
#             GEOID  longitude STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 0    010030114182 -87.640555      01      003  011418        2
# 1    010030107102 -87.872939      01      003  010710        2
# 2    010030107091 -87.868958      01      003  010709        1
# 3    010030107092 -87.843970      01      003  010709        2
# 4    010030114111 -87.695312      01      003  011411        1
# ..            ...        ...     ...      ...     ...      ...
# 112  010030114133 -87.652532      01      003  011413        3
# 113  010030105003 -87.766044      01      003  010500        3
# 114  010030103003 -87.881134      01      003  010300        3
# 115  010030111021 -87.842254      01      003  011102        1
# 116  010030116013 -87.525602      01      003  011601        3
#
#                   AFFGEOID NAME       NAMELSAD LSAD      ALAND   latitude
# 0    1500000US010030114182    2  Block Group 2   BG   13427709  30.263125
# 1    1500000US010030107102    2  Block Group 2   BG    7337867  30.620325
# 2    1500000US010030107091    1  Block Group 1   BG   18856416  30.574653
# 3    1500000US010030107092    2  Block Group 2   BG   13813181  30.618773
# 4    1500000US010030114111    1  Block Group 1   BG    6444709  30.342240
# ..                     ...  ...            ...  ...        ...        ...
# 112  1500000US010030114133    3  Block Group 3   BG    8748072  30.307268
# 113  1500000US010030105003    3  Block Group 3   BG    8840986  30.908131
# 114  1500000US010030103003    3  Block Group 3   BG  169059763  30.887916
# 115  1500000US010030111021    1  Block Group 1   BG   25397195  30.462849
# 116  1500000US010030116013    3  Block Group 3   BG   39716363  30.371114
#
# [117 rows x 12 columns]

# %%
# %%sql
# SELECT * FROM census_blocks WHERE length(AFFGEOID) = 21;
# Out:
#                GEOID   longitude STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 0       320030016112 -115.069852      32      003  001611        2
# 1       320050011001 -119.732187      32      005  001100        1
# 2       320030019011 -115.128058      32      003  001901        1
# 3       320310035102 -119.737654      32      031  003510        2
# 4       320030002042 -115.166600      32      003  000204        2
# ...              ...         ...     ...      ...     ...      ...
# 242379  410379602002 -120.345493      41      037  960200        2
# 242380  391517112023  -81.592984      39      151  711202        3
# 242381  420430248012  -76.850705      42      043  024801        2
# 242382  290950129062  -94.501158      29      095  012906        2
# 242383  080590120492 -105.062913      08      059  012049        2
#
#                      AFFGEOID NAME       NAMELSAD LSAD     ALAND   latitude
# 0       1500000US320030016112    2  Block Group 2   BG    663342  36.148129
# 1       1500000US320050011001    1  Block Group 1   BG   2022004  38.883508
# 2       1500000US320030019011    1  Block Group 1   BG    209570  36.141856
# 3       1500000US320310035102    2  Block Group 2   BG    594717  39.588675
# 4       1500000US320030002042    2  Block Group 2   BG   1144494  36.150667
# ...                       ...  ...            ...  ...       ...        ...
# 242379  1500000US410379602002    2  Block Group 2   BG  29143862  42.225239
# 242380  1500000US391517112023    3  Block Group 3   BG   9098005  40.864320
# 242381  1500000US420430248012    2  Block Group 2   BG  42952455  40.503264
# 242382  1500000US290950129062    2  Block Group 2   BG    976159  38.948447
# 242383  1500000US080590120492    2  Block Group 2   BG    996771  39.607014
#
# [242384 rows x 12 columns]

# %% [markdown]
# All entries in the AFFGEOID column are 21 characters long, so to match with the geoids in the 'poverty_county' table, I can
# remove the first character of each (since they do not match up on the tables), and remove the last 7 of the AFFGEOID for now
#
# Altered AFFGEOID table will be created as census_alt
#
# Altered poverty table will be saved as poverty_alt

# %%
# %%sql
#
# CREATE TABLE census_alt_test AS
# SELECT
#     *,
#     SUBSTRING(AFFGEOID, 2, LENGTH(AFFGEOID) - 8) AS modified_AFFGEOID
# FROM
#     census_blocks;
# Out:
#     Count
# 0  242384

# %%
# %%sql
# SELECT * FROM census_alt_test LIMIT 10;
# Out:
#           GEOID   longitude STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 0  320030016112 -115.069852      32      003  001611        2
# 1  320050011001 -119.732187      32      005  001100        1
# 2  320030019011 -115.128058      32      003  001901        1
# 3  320310035102 -119.737654      32      031  003510        2
# 4  320030002042 -115.166600      32      003  000204        2
# 5  320310035173 -119.673950      32      031  003517        3
# 6  320310032073 -119.750902      32      031  003207        3
# 7  350619703062 -106.668706      35      061  970306        2
# 8  350280005004 -106.290577      35      028  000500        4
# 9  360179702022  -75.728929      36      017  970202        2
#
#                 AFFGEOID NAME       NAMELSAD LSAD      ALAND   latitude  \
# 0  1500000US320030016112    2  Block Group 2   BG     663342  36.148129
# 1  1500000US320050011001    1  Block Group 1   BG    2022004  38.883508
# 2  1500000US320030019011    1  Block Group 1   BG     209570  36.141856
# 3  1500000US320310035102    2  Block Group 2   BG     594717  39.588675
# 4  1500000US320030002042    2  Block Group 2   BG    1144494  36.150667
# 5  1500000US320310035173    3  Block Group 3   BG     625323  39.612950
# 6  1500000US320310032073    3  Block Group 3   BG   25566087  39.305116
# 7  1500000US350619703062    2  Block Group 2   BG    8828015  34.778454
# 8  1500000US350280005004    4  Block Group 4   BG   53076356  35.802870
# 9  1500000US360179702022    2  Block Group 2   BG  114826135  42.655981
#
#   modified_AFFGEOID
# 0     500000US32003
# 1     500000US32005
# 2     500000US32003
# 3     500000US32031
# 4     500000US32003
# 5     500000US32031
# 6     500000US32031
# 7     500000US35061
# 8     500000US35028
# 9     500000US36017

# %%
# %%sql
# CREATE TABLE census_alt AS
# SELECT * FROM census_alt_test;
# Out:
#     Count
# 0  242384

# %% [markdown]
# Was able to succesfully make the matching geoid in the column 'modified_AFFGEOID' in table census_alt

# %%
# %%sql
# UPDATE poverty_county
# SET GEOID = SUBSTRING(GEOID, 2);
# Out:
#    Count
# 0    807

# %%
# %%sql
# SELECT * FROM poverty_county LIMIT 1000;
# Out:
#      TBLID          GEOID                                            GEONAME  \
# 0    R1701  500000US01003                            Baldwin County, Alabama
# 1    R1701  500000US01015                            Calhoun County, Alabama
# 2    R1701  500000US01043                            Cullman County, Alabama
# 3    R1701  500000US01049                             DeKalb County, Alabama
# 4    R1701  500000US01051                             Elmore County, Alabama
# ..     ...            ...                                                ...
# 802  R1701    30M600US356           Macon-Bibb County--Warner Robins, GA CSA
# 803  R1701  00C100US03763     Athens-Clarke County, GA Urbanized Area (2010)
# 804  R1701  00C100US04222  Augusta-Richmond County, GA--SC Urbanized Area...
# 805  R1701  00C100US43669  Kailua (Honolulu County)--Kaneohe, HI Urbanize...
# 806  R1701  00C100US51755  Louisville/Jefferson County, KY--IN Urbanized ...
#
#      PROFLN  ESTIMATE MG_ERROR
# 0        55      10.8   +/-2.2
# 1        55      19.8   +/-3.5
# 2        55      13.0   +/-3.7
# 3        55      21.3   +/-4.6
# 4        55      11.5   +/-3.2
# ..      ...       ...      ...
# 802      55      17.0   +/-2.0
# 803      55      20.2   +/-3.0
# 804      55      16.2   +/-2.0
# 805      55       6.5   +/-2.3
# 806      55      13.3   +/-1.1
#
# [807 rows x 6 columns]

# %%
# %%sql
# CREATE TABLE poverty_latlong_alt AS
# SELECT
#     poverty_county.GEONAME,
#     poverty_county.GEOID,
#     poverty_county.ESTIMATE,
#     poverty_county.MG_ERROR,
#     census_alt.longitude,
#     census_alt.latitude
# FROM
#     poverty_county
# LEFT JOIN
#     census_alt
# ON
#     poverty_county.GEOID = census_alt."modified_AFFGEOID";
# Out:
#     Count
# 0  190485

# %%
# %%sql
# SELECT * FROM poverty_latlong_alt LIMIT 200000;
# Out:
#                                                   GEONAME          GEOID  \
# 0                                    Clark County, Nevada  500000US32003
# 1                                    Clark County, Nevada  500000US32003
# 2                                   Washoe County, Nevada  500000US32031
# 3                                    Clark County, Nevada  500000US32003
# 4                                   Washoe County, Nevada  500000US32031
# ...                                                   ...            ...
# 190480  Louisville/Jefferson County--Elizabethtown--Ba...    30M600US350
# 190481     Athens-Clarke County, GA Urbanized Area (2010)  00C100US03763
# 190482  Augusta-Richmond County, GA--SC Urbanized Area...  00C100US04222
# 190483      Louisville/Jefferson County, KY-IN Metro Area  10M600US31140
# 190484  Kailua (Honolulu County)--Kaneohe, HI Urbanize...  00C100US43669
#
#         ESTIMATE MG_ERROR   longitude   latitude
# 0           15.1   +/-0.8 -115.069852  36.148129
# 1           15.1   +/-0.8 -115.128058  36.141856
# 2           11.2   +/-1.4 -119.737654  39.588675
# 3           15.1   +/-0.8 -115.166600  36.150667
# 4           11.2   +/-1.4 -119.673950  39.612950
# ...          ...      ...         ...        ...
# 190480      12.2   +/-0.9         NaN        NaN
# 190481      20.2   +/-3.0         NaN        NaN
# 190482      16.2   +/-2.0         NaN        NaN
# 190483      12.1   +/-0.9         NaN        NaN
# 190484       6.5   +/-2.3         NaN        NaN
#
# [190485 rows x 6 columns]

# %%
# %%sql
# SELECT * FROM poverty_latlong_alt WHERE latitude IS NULL LIMIT 1000;
# Out:
#                                               GEONAME          GEOID  \
# 0                 Athens-Clarke County, GA Metro Area  10M600US12020
# 1   Louisville/Jefferson County, KY--IN Urbanized ...  00C100US51755
# 2            Macon-Bibb County--Warner Robins, GA CSA    30M600US356
# 3                    Macon-Bibb County, GA Metro Area  10M600US31420
# 4           Augusta-Richmond County, GA-SC Metro Area  10M600US12260
# 5   Atlanta--Athens-Clarke County--Sandy Springs, ...    30M600US122
# 6   Louisville/Jefferson County--Elizabethtown--Ba...    30M600US350
# 7      Athens-Clarke County, GA Urbanized Area (2010)  00C100US03763
# 8   Augusta-Richmond County, GA--SC Urbanized Area...  00C100US04222
# 9       Louisville/Jefferson County, KY-IN Metro Area  10M600US31140
# 10  Kailua (Honolulu County)--Kaneohe, HI Urbanize...  00C100US43669
#
#     ESTIMATE MG_ERROR  longitude  latitude
# 0       16.9   +/-2.0        NaN       NaN
# 1       13.3   +/-1.1        NaN       NaN
# 2       17.0   +/-2.0        NaN       NaN
# 3       20.8   +/-2.8        NaN       NaN
# 4       15.8   +/-1.6        NaN       NaN
# 5       12.0   +/-0.5        NaN       NaN
# 6       12.2   +/-0.9        NaN       NaN
# 7       20.2   +/-3.0        NaN       NaN
# 8       16.2   +/-2.0        NaN       NaN
# 9       12.1   +/-0.9        NaN       NaN
# 10       6.5   +/-2.3        NaN       NaN

# %%
# %%sql
#
# SELECT GEOID, COUNT(GEOID) AS count
# FROM poverty_latlong_alt
# GROUP BY GEOID
# HAVING COUNT(GEOID) > 1;
# Out:
#              GEOID  count
# 0    500000US36081   1796
# 1    500000US36103   1058
# 2    500000US25025    681
# 3    500000US36059   1134
# 4    500000US51153    285
# ..             ...    ...
# 791  500000US04001     56
# 792  500000US48037     80
# 793  500000US40027    237
# 794  500000US35043     88
# 795  500000US49053     94
#
# [796 rows x 2 columns]

# %% [markdown]
# The above cell shows that there are a lot of duplicate GEOIDs, which makes sense as there are ~190,000 rows

# %%
# %%sql
#
# SELECT * FROM poverty_latlong_alt WHERE GEOID LIKE '500000US36081';
# Out:
#                       GEONAME          GEOID  ESTIMATE MG_ERROR  longitude  \
# 0     Queens County, New York  500000US36081      13.5   +/-0.8 -73.887012
# 1     Queens County, New York  500000US36081      13.5   +/-0.8 -73.891042
# 2     Queens County, New York  500000US36081      13.5   +/-0.8 -73.906678
# 3     Queens County, New York  500000US36081      13.5   +/-0.8 -73.798223
# 4     Queens County, New York  500000US36081      13.5   +/-0.8 -73.752770
# ...                       ...            ...       ...      ...        ...
# 1791  Queens County, New York  500000US36081      13.5   +/-0.8 -73.931156
# 1792  Queens County, New York  500000US36081      13.5   +/-0.8 -73.791235
# 1793  Queens County, New York  500000US36081      13.5   +/-0.8 -73.927796
# 1794  Queens County, New York  500000US36081      13.5   +/-0.8 -73.820111
# 1795  Queens County, New York  500000US36081      13.5   +/-0.8 -73.792944
#
#        latitude
# 0     40.720180
# 1     40.561945
# 2     40.707294
# 3     40.757069
# 4     40.703526
# ...         ...
# 1791  40.756162
# 1792  40.693887
# 1793  40.737111
# 1794  40.736575
# 1795  40.709831
#
# [1796 rows x 6 columns]

# %%
# %%sql
# SELECT GEONAME FROM poverty_latlong_alt GROUP BY GEONAME;
# Out:
#                                                GEONAME
# 0                              Queens County, New York
# 1                             Suffolk County, New York
# 2                        Suffolk County, Massachusetts
# 3                              Nassau County, New York
# 4                      Prince William County, Virginia
# ..                                                 ...
# 802                          Stearns County, Minnesota
# 803                    Davidson County, North Carolina
# 804                           Gallatin County, Montana
# 805  Louisville/Jefferson County--Elizabethtown--Ba...
# 806                       Rowan County, North Carolina
#
# [807 rows x 1 columns]

# %% [markdown]
# This GEOID was duplicated over 1750 times. All the estimate values are exactly the same, so this means we will not be losing data for the
# visualization of the counties if I remove the duplicates, as we only need one.

# %%
# %%sql
# CREATE TABLE temp_table AS
# SELECT MIN(id) AS min_id, GEOID
# FROM poverty_latlong_alt
# GROUP BY GEOID;
# Out:
#      TBLID          GEOID                                            GEONAME  \
# 0    R1701  500000US01003                            Baldwin County, Alabama
# 1    R1701  500000US01015                            Calhoun County, Alabama
# 2    R1701  500000US01043                            Cullman County, Alabama
# 3    R1701  500000US01049                             DeKalb County, Alabama
# 4    R1701  500000US01051                             Elmore County, Alabama
# ..     ...            ...                                                ...
# 802  R1701    30M600US356           Macon-Bibb County--Warner Robins, GA CSA
# 803  R1701  00C100US03763     Athens-Clarke County, GA Urbanized Area (2010)
# 804  R1701  00C100US04222  Augusta-Richmond County, GA--SC Urbanized Area...
# 805  R1701  00C100US43669  Kailua (Honolulu County)--Kaneohe, HI Urbanize...
# 806  R1701  00C100US51755  Louisville/Jefferson County, KY--IN Urbanized ...
#
#      PROFLN  ESTIMATE MG_ERROR
# 0        55      10.8   +/-2.2
# 1        55      19.8   +/-3.5
# 2        55      13.0   +/-3.7
# 3        55      21.3   +/-4.6
# 4        55      11.5   +/-3.2
# ..      ...       ...      ...
# 802      55      17.0   +/-2.0
# 803      55      20.2   +/-3.0
# 804      55      16.2   +/-2.0
# 805      55       6.5   +/-2.3
# 806      55      13.3   +/-1.1
#
# [807 rows x 6 columns]

# %%
# %%sql
# COPY (
#   SELECT * FROM poverty_latlong_alt
# ) TO '/Users/brenstockdale/Downloads/Data Downloads/adi-download-usa/poverty_latlong.parquet' (COMPRESSION ZSTD);
# Out:
#     Count
# 0  190485

# %%
poverty_latlong = pl.read_parquet('/Users/brenstockdale/Downloads/Data Downloads/adi-download-usa/poverty_latlong.parquet')

# %%
poverty_latlong.head()
# Out:
# shape: (5, 6)
# ┌───────────────────────┬───────────────┬──────────┬──────────┬─────────────┬───────────┐
# │ GEONAME               ┆ GEOID         ┆ ESTIMATE ┆ MG_ERROR ┆ longitude   ┆ latitude  │
# │ ---                   ┆ ---           ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ str                   ┆ str           ┆ f64      ┆ str      ┆ f64         ┆ f64       │
# ╞═══════════════════════╪═══════════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ Clark County, Nevada  ┆ 500000US32003 ┆ 15.1     ┆ +/-0.8   ┆ -115.069852 ┆ 36.148129 │
# │ Clark County, Nevada  ┆ 500000US32003 ┆ 15.1     ┆ +/-0.8   ┆ -115.128058 ┆ 36.141856 │
# │ Washoe County, Nevada ┆ 500000US32031 ┆ 11.2     ┆ +/-1.4   ┆ -119.737654 ┆ 39.588675 │
# │ Clark County, Nevada  ┆ 500000US32003 ┆ 15.1     ┆ +/-0.8   ┆ -115.1666   ┆ 36.150667 │
# │ Washoe County, Nevada ┆ 500000US32031 ┆ 11.2     ┆ +/-1.4   ┆ -119.67395  ┆ 39.61295  │
# └───────────────────────┴───────────────┴──────────┴──────────┴─────────────┴───────────┘

# %%
alt.Chart(poverty_latlong.sample(10000)).mark_circle(size=3).encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    # size='ADI_STATERNK:Q',
    # color='count()',
    tooltip=['GEOID:N', 'ADI_NATRANK:Q', 'ADI_STATERNK:Q']
).project(
    type='albersUsa'
)
# Out:
# alt.Chart(...)
